# %%
import pandas as pd
from tqdm import tqdm
tqdm.pandas()
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
import torch

import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

import nltk
nltk.download('stopwords')
nltk.download('punkt')

stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\maddy\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\maddy\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
reviews = pd.read_pickle('Pickle/reviews.pkl')

# %%
reviews
# Out:
#                                review_id  rating  \
# 0       5cd416f3efc3f944fce4ce2db2290d5e       5
# 1       dfdbb7b0eb5a7e4c26d59a937e2e5feb       5
# 2       5e212a62bced17b4dbe41150e5bb9037       3
# 3       fdd13cad0695656be99828cd75d6eb73       4
# 4       bd0df91c9d918c0e433b9ab3a9a5c451       4
# ...                                  ...     ...
# 999995  d53ddb7d0ee121a47e8d1ed144f04709       0
# 999996  ecfec5fc89629da466d5c49358e55a33       4
# 999997  6afb14b8dc8e42dbef89964bce8586cc       4
# 999998  884fb68ca4e27d3a255d37620fc438e5       0
# 999999  5cbc5b0ee190302b70f6360bc1383743       0
#
#                                               review_text  n_votes  \
# 0       Mind blowingly cool. Best science fiction I've...       16
# 1       This is a special book. It started slow for ab...       28
# 2       I haven't read a fun mystery book in a while a...        6
# 3       Fun, fast paced, and disturbing tale of murder...       22
# 4       A fun book that gives you a sense of living in...        8
# ...                                                   ...      ...
# 999995  I GIVE THIS BOOK: 3 1/2 out of 5 stars \n This...        0
# 999996  I read a .pdf version of this book that was se...        0
# 999997  "Every now and then, you have an encounter wit...        0
# 999998  I GIVE THIS BOOK: 4 1/2 out of 5 stars \n This...        0
# 999999  This is a very easy and tidy read. Sometimes I...        0
#
#         n_comments  user_id  book_id
# 0                0        0       14
# 1                1        0       21
# 2                0        0       22
# 3                4        0       23
# 4                0        0       24
# ...            ...      ...      ...
# 999995           0    26619    34363
# 999996           0    26619   125749
# 999997           0    26619   248053
# 999998           0    26619    35425
# 999999           0    26619   387204
#
# [1000000 rows x 7 columns]

# %%
#tokenizer and model
model_name = "distilbert-base-uncased-finetuned-sst-2-english"
tokenizer = AutoTokenizer.from_pretrained(model_name, model_max_length=512)
model = AutoModelForSequenceClassification.from_pretrained(model_name)
sentiment_pipeline = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# %%
def preprocess_text(text):
    text = re.sub(r'http\S+', '', text)
    words = word_tokenize(text)
    filtered_words = [word for word in words if word.isalnum() and word.lower() not in stop_words]
    cleaned_text = ' '.join(filtered_words)
    
    return cleaned_text

# %%
def truncate_text(text): 
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding="max_length", max_length=512) 
    truncated_text = tokenizer.decode(inputs['input_ids'][0], skip_special_tokens=True) 
    return truncated_text

# %%
reviews['cleaned_text'] = reviews['review_text'].progress_apply(preprocess_text)
reviews['truncated_text'] = reviews['cleaned_text'].progress_apply(truncate_text)
# Out:
#   2%|▏         | 17556/1000000 [00:10<09:46, 1675.47it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 reviews['cleaned_text'] = reviews['review_text'].progress_apply(preprocess_text)
#       2 reviews['truncated_text'] = reviews['cleaned_text'].progress_apply(truncate_text)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\tqdm\std.py:917, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     914 # Apply the provided function (in **kwargs)
#     915 # on the df using our wrapper (which provides bar updating)
#     916 try:
# --> 917     return getattr(df, df_function)(wrapper, **kwargs)
#     918 finally:
#     919     t.close()
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\tqdm\std.py:912, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     906 def wrapper(*args, **kwargs):
#     907     # update tbar correctly
#     908     # it seems `pandas apply` calls `func` twice
#     909     # on the first column/row to decide whether it can
#     910     # take a fast or slow code path; so stop when t.total==t.n
#     911     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 912     return func(*args, **kwargs)
#
# Cell In[15], line 3, in preprocess_text(text)
#       1 def preprocess_text(text):
#       2     text = re.sub(r'http\S+', '', text)
# ----> 3     words = word_tokenize(text)
#       4     filtered_words = [word for word in words if word.isalnum() and word.lower() not in stop_words]
#       5     cleaned_text = ' '.join(filtered_words)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\nltk\tokenize\__init__.py:144, in word_tokenize(text, language, preserve_line)
#     128 """
#     129 Return a tokenized copy of *text*,
#     130 using NLTK's recommended word tokenizer
#    (...)
#     140 :type preserve_line: bool
#     141 """
#     142 sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143 return [
# --> 144     token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145 ]
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\nltk\tokenize\destructive.py:182, in NLTKWordTokenizer.tokenize(self, text, convert_parentheses, return_str)
#     179     text = regexp.sub(substitution, text)
#     181 for regexp in self.CONTRACTIONS2:
# --> 182     text = regexp.sub(r" \1 \2 ", text)
#     183 for regexp in self.CONTRACTIONS3:
#     184     text = regexp.sub(r" \1 \2 ", text)
#
# KeyboardInterrupt:

# %%
reviews['truncated_text']
# Out:
# 0         mind blowingly cool best science fiction read ...
# 2         read fun mystery book sure ever read poirot lo...
# 6         giving high rating heard organizer long founda...
# 7         decided give eating processed sugar month janu...
# 9         kevin kelly wired lays technological trends in...
#                                 ...
# 999991    admit quite understand stories like book found...
# 999992    author weaved tale romance daily family life w...
# 999997    every encounter someone simply changes life co...
# 999998    give book 4 5 stars first official book parano...
# 999999    easy tidy read sometimes wonder grew different...
# Name: truncated_text, Length: 500000, dtype: object

# %%
# Function to get sentiment for each preprocessed and truncated review
def get_review_sentiment(review_text):
    # Ensure review_text is a string
    if isinstance(review_text, str):
        try:
            result = sentiment_pipeline(review_text)[0]
            return result['label'], result['score']
        except Exception as e:
            print(f"Error processing review_text: {review_text}")
            print(e)
            return None, None
    else:
        return None, None

# Get sentiment for all truncated reviews with debugging
sentiments = []
confidence_scores = []

for review in tqdm(reviews['truncated_text']):
    sentiment, confidence = get_review_sentiment(review)
    sentiments.append(sentiment)
    confidence_scores.append(confidence)

reviews['sentiment'] = sentiments
reviews['confidence'] = confidence_scores
# Out:
#   2%|▏         | 8582/500000 [09:38<9:12:33, 14.82it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 20
#      17 confidence_scores = []
#      19 for review in tqdm(reviews['truncated_text']):
# ---> 20     sentiment, confidence = get_review_sentiment(review)
#      21     sentiments.append(sentiment)
#      22     confidence_scores.append(confidence)
#
# Cell In[10], line 6, in get_review_sentiment(review_text)
#       4 if isinstance(review_text, str):
#       5     try:
# ----> 6         result = sentiment_pipeline(review_text)[0]
#       7         return result['label'], result['score']
#       8     except Exception as e:
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\transformers\pipelines\text_classification.py:156, in TextClassificationPipeline.__call__(self, inputs, **kwargs)
#     122 """
#     123 Classify the text(s) given as inputs.
#     124
#    (...)
#     153     If `top_k` is used, one such dictionary is returned per label.
#     154 """
#     155 inputs = (inputs,)
# --> 156 result = super().__call__(*inputs, **kwargs)
#     157 # TODO try and retrieve it in a nicer way from _sanitize_parameters.
#     158 _legacy = "top_k" not in kwargs
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\transformers\pipelines\base.py:1268, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1260     return next(
#    1261         iter(
#    1262             self.get_iterator(
#    (...)
#    1265         )
#    1266     )
#    1267 else:
# -> 1268     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\transformers\pipelines\base.py:1275, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1273 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1274     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1275     model_outputs = self.forward(model_inputs, **forward_params)
#    1276     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1277     return outputs
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\transformers\pipelines\base.py:1175, in Pipeline.forward(self, model_inputs, **forward_params)
#    1173     with inference_context():
#    1174         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1175         model_outputs = self._forward(model_inputs, **forward_params)
#    1176         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1177 else:
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\transformers\pipelines\text_classification.py:187, in TextClassificationPipeline._forward(self, model_inputs)
#     185 if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     186     model_inputs["use_cache"] = False
# --> 187 return self.model(**model_inputs)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:883, in DistilBertForSequenceClassification.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     875 r"""
#     876 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     877     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#     878     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     879     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     880 """
#     881 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 883 distilbert_output = self.distilbert(
#     884     input_ids=input_ids,
#     885     attention_mask=attention_mask,
#     886     head_mask=head_mask,
#     887     inputs_embeds=inputs_embeds,
#     888     output_attentions=output_attentions,
#     889     output_hidden_states=output_hidden_states,
#     890     return_dict=return_dict,
#     891 )
#     892 hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#     893 pooled_output = hidden_state[:, 0]  # (bs, dim)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:703, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     700     if attention_mask is None:
#     701         attention_mask = torch.ones(input_shape, device=device)  # (bs, seq_length)
# --> 703 return self.transformer(
#     704     x=embeddings,
#     705     attn_mask=attention_mask,
#     706     head_mask=head_mask,
#     707     output_attentions=output_attentions,
#     708     output_hidden_states=output_hidden_states,
#     709     return_dict=return_dict,
#     710 )
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:464, in Transformer.forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     456     layer_outputs = self._gradient_checkpointing_func(
#     457         layer_module.__call__,
#     458         hidden_state,
#    (...)
#     461         output_attentions,
#     462     )
#     463 else:
# --> 464     layer_outputs = layer_module(
#     465         hidden_state,
#     466         attn_mask,
#     467         head_mask[i],
#     468         output_attentions,
#     469     )
#     471 hidden_state = layer_outputs[-1]
#     473 if output_attentions:
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:408, in TransformerBlock.forward(self, x, attn_mask, head_mask, output_attentions)
#     405 sa_output = self.sa_layer_norm(sa_output + x)  # (bs, seq_length, dim)
#     407 # Feed Forward Network
# --> 408 ffn_output = self.ffn(sa_output)  # (bs, seq_length, dim)
#     409 ffn_output: torch.Tensor = self.output_layer_norm(ffn_output + sa_output)  # (bs, seq_length, dim)
#     411 output = (ffn_output,)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:343, in FFN.forward(self, input)
#     342 def forward(self, input: torch.Tensor) -> torch.Tensor:
# --> 343     return apply_chunking_to_forward(self.ff_chunk, self.chunk_size_feed_forward, self.seq_len_dim, input)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\transformers\pytorch_utils.py:248, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     245     # concatenate output at same dimension
#     246     return torch.cat(output_chunks, dim=chunk_dim)
# --> 248 return forward_fn(*input_tensors)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:348, in FFN.ff_chunk(self, input)
#     346 x = self.lin1(input)
#     347 x = self.activation(x)
# --> 348 x = self.lin2(x)
#     349 x = self.dropout(x)
#     350 return x
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\maddy\anaconda3\envs\goodreads\Lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
reviews
# Out:
#                                review_id  rating  \
# 292265  a5b74bfc7d877e0b6bbbdc7a6caaf19e       4
# 247357  2824edc9861b0728abd34e39931d9863       5
# 934030  7e956964da7e818b93b5bdbc371b8e0b       4
# 983180  7d6ad0c2285ac67da795a28ae3bfdd9b       2
# 859448  0b5d62ecdd7bef683a9fda60271ac5da       4
# ...                                  ...     ...
# 682789  eea0a83ebf2e08c55b8f768528903084       4
# 541785  aa48c575c42560a9efe8b61d26d6da5e       3
# 309356  dc9976808ddeb0d2404d1466f5fc9443       3
# 242581  ff8d3d55345351d83eb3af764737924b       3
# 60634   1b7bc155b025e9d7515ad6190e29ebdd       5
#
#                                               review_text  n_votes  \
# 292265  I only read "Dead Sleep" out of this 3 pack. F...        0
# 247357  A rich, hilarious commentary on American life ...        0
# 934030  This book connected with me in several ways. A...        0
# 983180  Review from Backchatting Books \n "By Proxy" i...        0
# 859448  Invasion of Privacy is a collection of short s...        1
# ...                                                   ...      ...
# 682789  Excellent read! Kaitlin and Beckett have alway...        0
# 541785  The Pact is definitely a love story. It tells ...        0
# 309356  So I do these kind of notes/stream of consciou...        0
# 242581  3+ stars! That was fun. Pretty over the top, b...        0
# 60634                                           very good        0
#
#         n_comments  user_id  book_id  \
# 292265           0     7587   662027
# 247357           0     6378    18789
# 934030           0    24481    46486
# 983180           0    26062    11563
# 859448           0    22534   864957
# ...            ...      ...      ...
# 682789           0    17844    64761
# 541785           0    14255   270087
# 309356           0     8065    45577
# 242581           0     6193   103537
# 60634            0     1636    20875
#
#                                                embeddings  \
# 292265  [-0.0054971282, -0.058966663, -0.07498373, 0.0...
# 247357  [-0.043407183, -0.021091254, -0.064387016, 0.0...
# 934030  [-0.00627925, -0.0045137024, -0.038882494, 0.0...
# 983180  [-0.07532537, -0.048045207, 0.019663217, 0.091...
# 859448  [-0.01699472, -0.026205948, -0.01679936, -0.02...
# ...                                                   ...
# 682789  [-0.0140506495, 0.019863551, -0.032689232, 0.0...
# 541785  [-0.020619314, 0.02975724, 0.006408088, -0.018...
# 309356  [-0.12945415, -0.056942053, -0.05114944, 0.003...
# 242581  [-0.031406842, -0.03604886, -0.0071208486, 0.0...
# 60634   [-0.09832179, 0.014489319, -0.016869541, 0.000...
#
#                                              cleaned_text  \
# 292265  read Dead Sleep 3 pack reason particular title...
# 247357       rich hilarious commentary American life time
# 934030  book connected several ways academician dazzle...
# 983180  Review Backchatting Books Proxy debut novel Ka...
# 859448  Invasion Privacy collection short stories stor...
# ...                                                   ...
# 682789  Excellent read Kaitlin Beckett always verbal s...
# 541785  Pact definitely love story tells compelling ta...
# 309356  kind consciousness reviews usually hope mind M...
# 242581               stars fun Pretty top fun nonetheless
# 60634                                                good
#
#                                            truncated_text sentiment  \
# 292265  read dead sleep 3 pack reason particular title...  NEGATIVE
# 247357       rich hilarious commentary american life time  POSITIVE
# 934030  book connected several ways academician dazzle...  POSITIVE
# 983180  review backchatting books proxy debut novel ka...  NEGATIVE
# 859448  invasion privacy collection short stories stor...  POSITIVE
# ...                                                   ...       ...
# 682789  excellent read kaitlin beckett always verbal s...  POSITIVE
# 541785  pact definitely love story tells compelling ta...  POSITIVE
# 309356  kind consciousness reviews usually hope mind m...  NEGATIVE
# 242581               stars fun pretty top fun nonetheless  POSITIVE
# 60634                                                good  POSITIVE
#
#         confidence
# 292265    0.866768
# 247357    0.999865
# 934030    0.547672
# 983180    0.993422
# 859448    0.993304
# ...            ...
# 682789    0.997185
# 541785    0.901370
# 309356    0.971502
# 242581    0.999871
# 60634     0.999816
#
# [1000 rows x 12 columns]
