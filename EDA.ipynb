# %%
import pandas as pd
read = pd.read_feather('Feather/read.feather')
books = pd.read_feather('Feather/books.feather')    
reviews = pd.read_feather('Feather/reviews.feather')
interactions = pd.read_feather('Feather/interactions.feather')

# %%
read.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228648342 entries, 0 to 228648341
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   user_id      int64
#  1   book_id      int64
#  2   is_read      int64
#  3   rating       int64
#  4   is_reviewed  int64
# dtypes: int64(5)
# memory usage: 8.5 GB

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   language_code  200000 non-null  object
#  1   description    200000 non-null  object
#  2   authors        200000 non-null  object
#  3   book_id        200000 non-null  int64
#  4   title          200000 non-null  object
#  5   genres         200000 non-null  object
#  6   combined_text  200000 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 10.7+ MB

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   review_id    200000 non-null  object
#  1   rating       200000 non-null  int64
#  2   review_text  200000 non-null  object
#  3   user_id      200000 non-null  int64
#  4   book_id      200000 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 7.6+ MB

# %%
interactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   review_id  200000 non-null  object
#  1   is_read    200000 non-null  bool
#  2   rating     200000 non-null  int64
#  3   user_id    200000 non-null  int64
#  4   book_id    200000 non-null  int64
# dtypes: bool(1), int64(3), object(1)
# memory usage: 6.3+ MB

# %%
books['language_code'].unique()
# Out:
# array(['', 'eng', 'en-US', 'fre', 'spa', 'mul', 'en-GB', 'enm', 'en-CA',
#        'ger', 'ita', 'glg', 'swe', 'tur', 'por', 'ara', 'grc', 'pol',
#        'per', 'kor', 'dan', 'fin', 'nor', 'jpn', 'hun', 'rus', 'nob',
#        'hye', 'zho', 'tlh', 'ind', 'urd', 'frs', 'nl', 'ben', 'cze',
#        'ukr', 'msa', 'rum', '--', 'tgl', 'scr', 'lit', 'fil', 'isl',
#        'srp', 'cat', 'ang', 'pes', 'nno', 'mar', 'lav', 'lat', 'vie',
#        'heb', 'afr', 'pan', 'dut', 'bul', 'est', 'gre', 'nld', 'tha',
#        'hin', 'tam', 'kan', 'slv', 'bos', 'arg', 'dum', 'alg', 'slo',
#        'apa', 'sin', 'egy', 'aze', 'guj', 'mon', 'gla', 'sqi', 'jav',
#        'gle', 'en', 'mal', 'nep', 'wel', 'es-MX', 'vls', 'kat', 'mus',
#        'tel', 'iro', 'tut', 'mkd', 'pt-BR', 'kur', 'amh', 'din', 'crh',
#        'arw', 'snd', 'mya', 'ada', 'bel', 'smn', 'pra', 'mlt', 'fao',
#        'epo', 'abk', 'peo', 'ori', 'ota', 'udm', 'eus'], dtype=object)

# %%
books[books['language_code'] == 'enm']
# Out:
#     language_code                                        description  \
# 114           enm  On a spring day in April--sometime in the wani...
#
#                                                authors  book_id  \
# 114  [{'author_id': '1838', 'role': ''}, {'author_i...     2701
#
#                     title                                             genres  \
# 114  The Canterbury Tales  {'children': None, 'comics, graphic': None, 'f...
#
#                                          combined_text
# 114  On a spring day in April--sometime in the wani...

# %%
books[books['language_code'] == 'en-US']
# Out:
#        language_code                                        description  \
# 7              en-US  From one of America's most iconic writers, a s...
# 12             en-US  Inez Victor knows that the major casualty of t...
# 28             en-US  In the last decade, No Logo has become a cultu...
# 29             en-US
# 39             en-US  Since its publication in 1993, Paulo Coelho's ...
# ...              ...                                                ...
# 189581         en-US  The walk of shame.\nAh, yes, there's nothing q...
# 189752         en-US  A small farm community is the perfect place to...
# 189855         en-US  Words and Phrases: Make Your Sex Scenes Sizzle...
# 190037         en-US  A stolen crown. An unbreakable friendship. One...
# 190385         en-US  A new romantic action adventure for fans of ro...
#
#                                                   authors   book_id  \
# 7                      [{'author_id': '238', 'role': ''}]       420
# ...

# %%
books[books['language_code'] == 'eng']
# Out:
#        language_code                                        description  \
# 4                eng  Tom Wolfe, the master social novelist of our t...
# 8                eng  First published in 1979, "The White Album "is ...
# 9                eng  Writing with the telegraphic swiftness and mic...
# 10               eng  In her moving and insightful new book, Joan Di...
# 13               eng  (Book Jacket Status: Jacketed)\nJoan Didion's ...
# ...              ...                                                ...
# 199983           eng  Tobias\nComing home means coming hard.\nI've n...
# 199984           eng  An eclectic mix of short stories, which evolve...
# 199990           eng  Wonder Woman reconnects with Artemis. Plus, Di...
# 199992           eng  Jason Banks works for his father, who owns a h...
# 199994           eng  When there's trouble, he has your back.\nFor T...
#
#                                                   authors   book_id  \
# ...

# %%
books[books['language_code'] == 'en-GB']
# Out:
#        language_code                                        description  \
# 101            en-GB  Ed Bishop stars as Philip Marlowe in this atmo...
# 186            en-GB  High in the pine forests of the Spanish Sierra...
# 200            en-GB  In an open cart Elspeth Huxley set off with he...
# 216            en-GB  "So charged with pain and wonder that the nove...
# 224            en-GB  Fourth-grader Amber Brown must make some impor...
# ...              ...                                                ...
# 189458         en-GB  After her four sisters married for love, Mercy...
# 189728         en-GB  Natalie Banks is exactly where she wants to be...
# 190046         en-GB  Adopted as a baby, Giles Frobisher has grown u...
# 190159         en-GB  Zeke and I are finally together.\nGoing from b...
# 190249         en-GB  Millions of readers have fallen in love with A...
#
#                                                   authors   book_id  \
# ...

# %% [markdown]
# langauge code is not useful lots of gaps and inconsistencies

# %%
print('Number of users is {}'.format(len(interactions.user_id.unique())))
# Out:
# Number of users is 438

# %% [markdown]
# should this be in preprocessing

# %%
interactions[interactions['is_read']== True]
# Out:
#                                review_id  is_read  rating  user_id  book_id
# 13      ea74f2b6645b7d16f3ede2aca10226f0     True       0        0       13
# 14      5cd416f3efc3f944fce4ce2db2290d5e     True       5        0       14
# 21      dfdbb7b0eb5a7e4c26d59a937e2e5feb     True       5        0       21
# 22      5e212a62bced17b4dbe41150e5bb9037     True       3        0       22
# 23      fdd13cad0695656be99828cd75d6eb73     True       4        0       23
# ...                                  ...      ...     ...      ...      ...
# 199201  bef640ef9b737d530e67ca8f7b91fc27     True       5      437     1200
# 199245  450a571d8d243b04b09900cad52b92b6     True       5      437    98768
# 199387  3d2315ab64d3a69a2643c2fe5fcc5d5d     True       5      437      993
# 199828  26d6af65bac006c4a16b4abdce304e9c     True       5      437     1009
# 199852  392f6907882dfe7ffdb6d33026cc91e4     True       5      437    99207
#
# [103248 rows x 5 columns]
